# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # New Section

# %%
# input data
data_un=pd.read_excel(os.path.join("DataUN_Train.xlsx"),
     engine='openpyxl',)
# Menampilkan data
data_un.head(51)
# Out:
#     no  bhs_indo  bhs_ing   mtk  kimia  fisika   bio  ekonomi  geografi  \
# 0    0      70.6     64.3  46.4   55.1    66.8  47.9     77.8      48.6
# 1    1      46.4     81.0  69.5   65.1    66.6  81.6     57.9      63.1
# 2    2      81.3     52.2  55.1   62.4    83.9  56.2     60.0      48.1
# 3    3      50.0     59.1  50.7   69.2    66.9  70.0     55.9      56.3
# 4    4      64.1     69.0  66.6   44.1    61.9  46.1     83.8      73.4
# 5    5      70.6     50.3  47.9   41.0    50.3  51.6     42.4      38.1
# 6    6      59.7     55.8  47.8   57.8    58.4  67.5     68.6      66.3
# 7    7      50.2     51.3  52.9   60.0    56.7  64.1     50.3      58.3
# 8    8      65.4     60.8  64.9   55.4    41.0  44.0     58.0      48.5
# 9    9      43.6     49.8  53.5   53.2    45.9  43.8     75.8      67.8
# 10  10      56.6     64.2  41.5   47.4    50.1  51.3     56.0      70.9
# 11  11      81.5     66.9  55.9   56.3    63.2  50.1     65.3      73.1
# ...

# %%
data_un.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   no         51 non-null     int64
#  1   bhs_indo   51 non-null     float64
#  2   bhs_ing    51 non-null     float64
#  3   mtk        51 non-null     float64
#  4   kimia      51 non-null     float64
#  5   fisika     51 non-null     float64
#  6   bio        51 non-null     float64
#  7   ekonomi    51 non-null     float64
#  8   geografi   51 non-null     float64
#  9   sosiologi  51 non-null     float64
#  10  fakultas   51 non-null     object
# dtypes: float64(9), int64(1), object(1)
# memory usage: 4.5+ KB

# %%
data_un.empty
# Out:
# False

# %%
data_un.size
# Out:
# 561

# %%
from sklearn.cluster import KMeans
#Memvisualkan persebaran data
print("PERSEBARAN NILAI TERHADAP FAKULTAS\n")
plt.scatter(data_un.bhs_indo, data_un.fakultas, s = 75, c = "brown", 
            label='Bahasa Indonesia', marker = "o", alpha = 0.6)

plt.scatter(data_un.bhs_ing, data_un.fakultas, s = 75, c = "blue", 
            label='Bahasa Inggris', marker = "o", alpha = 0.6)

plt.scatter(data_un.mtk, data_un.fakultas, s = 75, c = "red", 
            label='Matematika', marker = "o", alpha = 0.6)

plt.scatter(data_un.kimia, data_un.fakultas, s = 75, c = "green", 
            label='Kimia', marker = "o", alpha = 0.6)

plt.scatter(data_un.fisika, data_un.fakultas, s = 75, c = "cyan", 
            label='Fisika', marker = "o", alpha = 0.6)

plt.scatter(data_un.bio, data_un.fakultas, s = 75, c = "purple", 
            label='Biologi', marker = "o", alpha = 0.6)

plt.scatter(data_un.ekonomi, data_un.fakultas, s = 75, c = "yellow", 
            label='Ekonomi', marker = "o", alpha = 0.6)

plt.scatter(data_un.geografi, data_un.fakultas, s = 75, c = "grey", 
            label='Geografi', marker = "o", alpha = 0.6)

plt.scatter(data_un.sosiologi, data_un.fakultas, s = 75, c = "pink", 
            label='Sosiologi', marker = "o", alpha = 0.6)



plt.legend(loc=1, prop={'size':10})
plt.show()
# Out:
# PERSEBARAN NILAI TERHADAP FAKULTAS

# %%
# Variabel independen
x = data_un.drop(['fakultas','no'], axis = 1)
x.head(51)
# Out:
#     bhs_indo  bhs_ing   mtk  kimia  fisika   bio  ekonomi  geografi  sosiologi
# 0       70.6     64.3  46.4   55.1    66.8  47.9     77.8      48.6       67.6
# 1       46.4     81.0  69.5   65.1    66.6  81.6     57.9      63.1       68.6
# 2       81.3     52.2  55.1   62.4    83.9  56.2     60.0      48.1       57.4
# 3       50.0     59.1  50.7   69.2    66.9  70.0     55.9      56.3       58.9
# 4       64.1     69.0  66.6   44.1    61.9  46.1     83.8      73.4       67.4
# 5       70.6     50.3  47.9   41.0    50.3  51.6     42.4      38.1       43.5
# 6       59.7     55.8  47.8   57.8    58.4  67.5     68.6      66.3       56.9
# 7       50.2     51.3  52.9   60.0    56.7  64.1     50.3      58.3       48.5
# 8       65.4     60.8  64.9   55.4    41.0  44.0     58.0      48.5       50.1
# 9       43.6     49.8  53.5   53.2    45.9  43.8     75.8      67.8       70.4
# 10      56.6     64.2  41.5   47.4    50.1  51.3     56.0      70.9       68.7
# ...

# %%
# Variabel dependen
y = data_un["fakultas"]
y.head(51)
# Out:
# 0                            Komunikasi
# 1                            Komunikasi
# 2                                 Hukum
# 3                       Kedokteran Umum
# 4                            Komunikasi
# 5     Teknologi Informasi/Ilmu Komputer
# 6                       Kedokteran Umum
# 7                       Kedokteran Umum
# 8                             Akuntansi
# 9                             Akuntansi
# 10                           Komunikasi
# 11                                Hukum
# 12                           Komunikasi
# 13                            Akuntansi
# 14    Teknologi Informasi/Ilmu Komputer
# 15                                Hukum
# 16                      Kedokteran Umum
# 17                                Hukum
# 18                      Kedokteran Umum
# 19                            Akuntansi
# 20                           Komunikasi
# 21                                Hukum
# 22                           Komunikasi
# ...

# %%
# Import train_test_split function
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data_un, y, test_size = 0.2, random_state = 123)

# %%
# Import Gaussian Naive Bayes model
from sklearn.naive_bayes import GaussianNB
import pickle
# Mengaktifkan/memanggil/membuat fungsi klasifikasi Naive bayes
modelnb = GaussianNB()
# Memasukkan data training pada fungsi klasifikasi naive bayes
nbtrain = modelnb.fit(x, y)
pickle.dump(nbtrain, open('finalized_model.sav', 'wb'))
Y_predict = nbtrain.predict(x)
print("Prediksi Naive Bayes : ",Y_predict)
# Out:
# Prediksi Naive Bayes :  ['Komunikasi' 'Komunikasi' 'Hukum' 'Hukum' 'Komunikasi'
#  'Teknologi Informasi/Ilmu Komputer' 'Akuntansi' 'Hukum' 'Akuntansi'
#  'Akuntansi' 'Komunikasi' 'Komunikasi' 'Komunikasi' 'Akuntansi'
#  'Teknologi Informasi/Ilmu Komputer' 'Hukum' 'Kedokteran Umum' 'Hukum'
#  'Hukum' 'Akuntansi' 'Komunikasi' 'Hukum' 'Komunikasi' 'Hukum'
#  'Kedokteran Umum' 'Komunikasi' 'Teknologi Informasi/Ilmu Komputer'
#  'Teknologi Informasi/Ilmu Komputer' 'Hukum' 'Akuntansi'
#  'Teknologi Informasi/Ilmu Komputer' 'Hukum' 'Hukum' 'Komunikasi' 'Hukum'
#  'Akuntansi' 'Komunikasi' 'Teknologi Informasi/Ilmu Komputer' 'Komunikasi'
#  'Teknologi Informasi/Ilmu Komputer' 'Komunikasi' 'Kedokteran Umum'
#  'Hukum' 'Akuntansi' 'Hukum' 'Teknologi Informasi/Ilmu Komputer'
#  'Akuntansi' 'Akuntansi' 'Komunikasi' 'Teknologi Informasi/Ilmu Komputer'
#  'Akuntansi']

# %%
from sklearn.metrics import accuracy_score
accuracy= accuracy_score(y, Y_predict)
print("Akurasi Naive Bayes : ",accuracy)
# Out:
# Akurasi Naive Bayes :  0.8235294117647058

# %%
# Menghitung nilai akurasi dari klasifikasi naive bayes 
from sklearn.metrics import classification_report
print(classification_report(y, Y_predict))
# Out:
#                                    precision    recall  f1-score   support
#
#                         Akuntansi       0.73      1.00      0.84         8
#                             Hukum       0.64      0.82      0.72        11
#                   Kedokteran Umum       1.00      0.33      0.50         9
#                        Komunikasi       0.93      1.00      0.96        13
# Teknologi Informasi/Ilmu Komputer       1.00      0.90      0.95        10
#
#                          accuracy                           0.82        51
#                         macro avg       0.86      0.81      0.79        51
#                      weighted avg       0.86      0.82      0.81        51

# %%
# input data
#data_tes=pd.read_excel('DataUN_Test.xlsx')
# Menampilkan data
#data_tes.head(4)

# %%
# creating an empty list
lst = []
  
# iterating till the range
for i in range(0, 9):
    ele = float(input())
  
    lst.append(ele) # adding the element
      
print(lst)

tes3 = nbtrain.predict([lst])
print(tes3)
# Out:
# [78.0, 94.0, 73.0, 87.0, 47.0, 87.0, 0.0, 0.0, 0.0]
# ['Teknologi Informasi/Ilmu Komputer']
